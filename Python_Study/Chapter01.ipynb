# %% [markdown]
# 텍스트셀
# - 메모장 처럼 사용.
# - 프로그렘 실행에 영향 주지 않음

# %%
print("안녕하세요")
# 주석 : 메모장처럼 사용, 프로그램 실행에는 영향을 주지 않음
# 코드 실행 단축기 : ctrl + enter
# 주석 단축기 : ctrl + /
# 코드셀 추가 단축키 : ctrl + M + B
# 코드셀 삭제 단축기 : ctrl + M + D
# Out:
# 안녕하세요
