# %% [markdown]
# ## 변수의 종류

# %%
global_value = 100 # 전역변수

def print_value(num) :  # 매개변수도 일종의 지역변수
    print(global_value) # 전역변수는 함수 내부에서도 사용 가능
    local_value = 200   # 지역변수
    print(local_value)
    print(num)


print(global_value)

#함수 호출
print_value(20)
# print(local_value) # 지역변수는 함수 밖에서 사용 불가 (오류발생)
# print(num)         # 매개변수도 함수 밖에서 사용 불가 (오류발생)
# Out:
# 100
# 100
# 200
# 20

# %% [markdown]
# ## 표준 모듈

# %% [markdown]
# ### 1) random 모듈

# %%
import random

# randint()
print(random.randint(1, 10)) # 1 ~ 10 중 랜덤한 정수 반환
# .(~의, ~안에) : random.randomint() => random 모듈 안의 randint()

# randrange()
print(random.randrange(10)) # 0 ~ 9 까지의 정수 중 랜덤한 정수 반환
print(random.randrange(2, 10)) # 2 ~ 9 까지의 정수 중 랜덤한 정수 반환
print(random.randrange(2, 10, 3)) # 2 ~ 9 간격은 3인 정수 중 랜덤한 정수 반환 (2, 5, 8)

# choice()
li = ["a", "b", "c"]
print(random.choice(li))

# sample()
print(random.sample(li, 2))
# Out:
# 6
# 3
# 8
# 2
# b
# ['c', 'b']

# %%
# 모듈에서 특정한 함수만 가져오기
from random import randint, randrange

print(randint(1,5)) # 특정 함수만 import할 경우 모듈명 작성하지 않아도 됨
print(randrange(1, 10))
# Out:
# 1
# 4

# %% [markdown]
# ### 2) time 모듈

# %%
import time

# sleep()
print("안녕하세요")
# time.sleep(3) # 3초 딜레이
print("안녕히계세요")

# time()
print(time.time())
# Out:
# 안녕하세요
# 안녕히계세요
# 1756183903.6939116

# %%
import matplotlib.pyplot as plt # 별칭

# matplotlib : 데이터 분석 시각화할 때 사용
# .plot(x, y) : x축 데이터, y축 데이터를 설정하여 꺾은 선 그래프를 작성

plt.plot([1, 2, 3, 4], ["a","b", "c", "d"])
plt.show # 그래프 출력
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
